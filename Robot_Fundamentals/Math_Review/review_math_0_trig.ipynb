# %% [markdown]
# # Trig Functions

# %%
# Step 1: Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ang = -135 * np.pi/180

s = np.sin(ang)
c = np.cos(ang)
t = np.tan(ang)

print(f"sin({ang}) = {s}")
print(f"cos({ang}) = {c}")
print(f"tan({ang}) = {t}")

arc_s = np.arcsin(s) * 180/np.pi
arc_c = np.arccos(c) * 180/np.pi
arc_t = np.arctan(t) * 180/np.pi

print(f"arcsin({s}) = {arc_s}")
print(f"arccos({c}) = {arc_c}")
print(f"arctan({t}) = {arc_t}")

# use atan2
t = np.arctan2(1, 1) * 180/np.pi
print(f"arctan2(1, 1) = {t}")
# Out:
# sin(-2.356194490192345) = -0.7071067811865476
# cos(-2.356194490192345) = -0.7071067811865475
# tan(-2.356194490192345) = 1.0000000000000002
# arcsin(-0.7071067811865476) = -45.00000000000001
# arccos(-0.7071067811865475) = 135.0
# arctan(1.0000000000000002) = 45.00000000000001
# arctan2(1, 1) = 45.0
